# %% [markdown]
# ## Image Processing in Python
#
# ### Diego Molla
#
# ### Reading
# * https://docs.python.org/3/tutorial/index.html

# %% [markdown]
# ## Program
#
# 1. **A Review of Python**
#    1. **Practicalities**
#    2. Basic Python
#    3. Vectors and Matrices in Python
#
# 2. Image Processing in Python

# %% [markdown]
# ## A Review of Python
#
# ### Why Python?
#
# * Rapid prototyping
#   * jupyter notebook
# * Platform neutral
# * Clean, object oriented
# * Good text manipulation
# * Wide range of libraries
#   * Specific libraries for text and image processing.
#   * pandas, sklearn, tensorflow for data mining.
#   * NumPy and SciPy for scientific computing.
#   * matplotlib and pyplot for plotting.

# %% [markdown]
# ## Installing Python
#
# * Official Python at http://www.python.org.
# * We will use the Anaconda Python environment from https://docs.anaconda.com/free/anaconda/.
# * Current version is 3.x. **do not use 2.x**.
# * Windows/Mac/Linux versions.
# * Download includes many libraries.
# * Anaconda includes Jupyter notebooks plus numerous libraries.

# %% [markdown]
# ## Popular IDEs for Python (according to https://hackr.io/blog/best-python-ide)
#
# 1. Pycharm https://www.jetbrains.com/pycharm/
# 2. Visual Studio Code https://code.visualstudio.com -- **My recommendation**
# 3. Jupyter Notebooks https://jupyter.org/
# 4. Eclipse + Pydev https://www.pydev.org/
# 5. IDLE https://docs.python.org/3/library/idle.html
# 6. Sublime Text http://www.sublimetext.com/
# 7. Spyder https://www.spyder-ide.org/
# 8. GNU Emacs https://www.gnu.org/software/emacs/
# 9. Wing https://wingware.com/
# 10. Thonny https://thonny.org/

# %% [markdown]
# ## Jupyter Notebooks
#
# <img src='Figs/Fig1.jpg' height="70%" width="70%" style='float:left; margin:10px'>

# %% [markdown]
# ## Program
#
# 1. **A Review of Python**
#    1. Practicalities
#    2. **Basic Python**
#    3. Vectors and Matrices in Python
#
# 2. Image Processing in Python

# %% [markdown]
# # Basic Python
# ### Beginning Python

# %%
def hello (who):                          # 1
    """Greet somebody"""                  # 2
    print("Hello " + who + "!")           # 3

# %% [markdown]
# 1. Defines a new function/procedure called `hello` which takes a single argument.  Note that python variables are not typed, who could be a string, integer, array ... The line ends with a colon (:) which means we're beginning an indented code block.
#
# 2. Firstly note that there are no brackets delimiting the body of the procedure, Python instead uses indentation to delimit code blocks. So, getting the indentation right is crucial!
#
#    This line (2) is a documentation string for the procedure which gets associated with it in the python environment. The three double quotes delimit a multi-line string (could use ' or " in this context).
#
# 3. This is the body of the procedure, ``print`` is a built in command in python. Note that the Python 2.x versions do not use round brackets, this is a major difference with Python 3.x. We also see here the `+` operator used on strings (I'm assuming `who`is a string) to perform concatenation --- thus we have operator overloading based on object type just like other OO languages.

# %%
help(hello)
# Out:
# Help on function hello in module __main__:
#
# hello(who)
#     Greet somebody

# %%
hello("Diego")
# Out:
# Hello Diego!

# %%
hello("Yuankai")
# Out:
# Hello Yuankai!

# %% [markdown]
# Here I'm calling the new procedure with a literal string argument delimited by `"`.

# %%
hello('world')
# Out:
# Hello world!

# %% [markdown]
# And here delimited by `'` --- both of these delimiters are equivalent, use one if you want to include the other in the string, eg `"Steve's"`.

# %%
people =  ['Diego', "Yuankai", 'Bilal', 'Abid']           # 6
for person in people:                                     # 7
    hello(person)                                         # 8
# Out:
# Hello Diego!
# Hello Yuankai!
# Hello Bilal!
# Hello Abid!

# %% [markdown]
# 6. This defines a variable people to have a value which is a list of strings, lists are 1-D arrays and the elements can be any python object (including lists).
#
# 7. A `for` loop over the elements of the list. Again the line ends with a colon indicating a code block to follow.
#
# 8. Call the procedure with the variable which will be bound to successive elements of the list.

# %% [markdown]
# ### Core Data Types
# 1. Strings
# 2. Numbers (integers, float, complex)
# 3. Lists
# 4. Tuples (immutable sequences)
# 5. Dictionaries (associative arrays)

# %% [markdown]
# ### Lists

# %%
a = ['one', 'two', 3, 'four']

# %%
a[0]
# Out:
# 'one'

# %%
a[-1]
# Out:
# 'four'

# %%
a[0:3]
# Out:
# ['one', 'two', 3]

# %%
len(a)
# Out:
# 4

# %%
len(a[0])
# Out:
# 3

# %%
a[1] = 2
a
# Out:
# ['one', 2, 3, 'four']

# %%
a.append('five')
a
# Out:
# ['one', 2, 3, 'four', 'five']

# %%
top = a.pop()
a
# Out:
# ['one', 2, 3, 'four']

# %%
top
# Out:
# 'five'

# %% [markdown]
# ### List Comprehensions

# %% [markdown]
# List comprehensions are a very powerful feature of Python. They reduce the need to write simple loops. For more details on list comprehensions: https://docs.python.org/3/tutorial/datastructures.html

# %%
a = ['one', 'two', 'three', 'four']
len(a[0])
# Out:
# 3

# %%
b = [w for w in a if len(w) > 3]
b
# Out:
# ['three', 'four']

# %% [markdown]
# The above code uses list comprehensions to implement the following loop:
#
# ```python
# b = []
# for w in a:
#     if len(w) > 3:
#         b.append(w)
# ```

# %%
c = [[1,'one'],[2,'two'],[3,'three']]
d = [w for n, w in c]
d
# Out:
# ['one', 'two', 'three']

# %% [markdown]
# The above code uses list comprehensions to implement the following loop:
# ```python
# d = []
# for n, w in c:
#     d.append(w)
# ```

# %% [markdown]
# ### Tuples
# Tuples are a sequence data type like lists but are immutable:
# * Once created, elements cannot be added or modified.
#
# Create tuples as literals using parentheses:

# %%
a  = ('one', 'two', 'three')

# %% [markdown]
# Or from another sequence type:

# %%
a = ['one', 'two', 'three']
b = tuple(a)

# %% [markdown]
# Use tuples as fixed length sequences: memory advantages.

# %% [markdown]
# ### Dictionaries
# * Associative array datatype (hash)
# * Store values under some hash key
# * Key can be any immutable type: string, number, tuple

# %%
names = dict()
names['madonna'] = 'Madonna'
names['john'] = ['Dr.', 'John', 'Marshall']
names.keys()
# Out:
# dict_keys(['madonna', 'john'])

# %%
list(names.keys())
# Out:
# ['madonna', 'john']

# %%
ages = {'steve':41, 'john':22}
'john' in ages
# Out:
# True

# %%
41 in ages
# Out:
# False

# %%
'john' in ages.keys()
# Out:
# True

# %%
for k in ages:
    print(k, ages[k])
# Out:
# steve 41
# john 22

# %% [markdown]
# ### Organising Source Code: Modules
# * In Python, a module is  a single source file wich defines one or more procedures or classes.
# * Load a module with the `import` directive.
# * After importing the module, all functions are grouped in the module namespace.
# * Python provides many useful modules.

# %% [markdown]
# ```python
# import mymodule
# ```
# This loads the file mymodule.py and evaluates its contents.
# * By default, all procedures are put into the mymodule namespace, accessed with a dotted notation:
#   * mymodule.test() — calls the test () procedure defined in mymodule.py
#
# Can import names into global namespace
# ```python
# from mymodule import test, doodle
# from mymodule import ∗
# ```

# %%
# The Python distribution comes with many useful modules.
import math
20 * math.log(3)
# Out:
# 21.972245773362197

# %% [markdown]
# ### Defining Modules
# * A module is a source file containing Python code
#     * Usually class/function definitions.
# * First non comment item can be a docstring for the module.
#
# ```python
# # my python module
# """This is a python module to
# do something interesting"""
#
# def foo(x):
#    'foo the x'
#    print('the foo is ' + str(x))
# ```

# %% [markdown]
# ## Program
#
# 1. **A Review of Python**
#    1. Practicalities
#    2. Basic Python
#    3. **Vectors and Matrices in Python**
#
# 2. Image Processing in Python

# %% [markdown]
# ## Vectors and Matrices in Python
#
# #### numpy
# * Python’s numpy is a collection of libraries that include manipulation of vectors and matrices.
# * http://www.numpy.org/
# * It’s pre-loaded in the Anaconda distribution.
#
# * Manipulating Vectors
# * Manipulating Matrices

# %% [markdown]
# ### Manipulating Vectors

# %%
import numpy as np
a = np.array([1,2,3,4])
a[0]
# Out:
# 1

# %%
# slicing
a[1:3]
# Out:
# array([2, 3])

# %%
# add a constant to a vector
a+1
# Out:
# array([2, 3, 4, 5])

# %%
# add two vectors
b = np.array([2,3,4,5])
a+b
# Out:
# array([3, 5, 7, 9])

# %%
# pairwise multiplication
a*b
# Out:
# array([ 2,  6, 12, 20])

# %%
# dot product between vectors, a.b
np.dot(a,b)
# Out:
# 40

# %% [markdown]
# ### Manipulating Matrices

# %%
x = np.array([[1,2,3],[4,5,6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# add two matrices
y = np.array([[1,1,1],[2,2,2]])
x+y
# Out:
# array([[2, 3, 4],
#        [6, 7, 8]])

# %%
# pairwise multiplication
x*y
# Out:
# array([[ 1,  2,  3],
#        [ 8, 10, 12]])

# %%
# transpose
x.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
# dot product
np.dot(x.T,y)
# Out:
# array([[ 9,  9,  9],
#        [12, 12, 12],
#        [15, 15, 15]])

# %% [markdown]
# ## Program
#
# 1. A Review of Python
#    1. Practicalities
#    2. Basic Python
#    3. Vectors and Matrices in Python
#
# 2. **Image Processing in Python**

# %% [markdown]
# ## Image Processing in Python
#
# * Images are represented as Python arrays.
# * The first 2 dimensions of the array represent the pixel.
# * The third dimension represents the pixel colour, which can be a vector.
# * Each element of the pixel vector represents a channel. There are several options:
#   * 3 channels for Red, Green, Blue.
#   * 4 channels for Red, Green, Blue, Alpha (transparency).
#   * There are other possibilities which we will not cover here.

# %% [markdown]
# ### Greyscale images
#
#
# Greyscale images are represented as a matrix such that:
#
# - Each element of the matrix represents a pixel in the image.
# - The value of the element represents the pixel intensity, from 0 (black) to 255 (white), or from 0 to 1

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

img = np.array([[   0, 255,   0],   #   black,  white,     black
                [  50, 200,  50],   #    dark,  light,      dark
                [ 110, 127, 140]])  # mid-dark,   mid, mid-light

plt.imshow(img, cmap='gray')

# %% [markdown]
# Let's read a greyscale image (images from https://www.linkedin.com/learning/computer-vision-deep-dive-in-python/).

# %%
greyimage = plt.imread('Figs/stickanimalsGray.png')
plt.imshow(greyimage, cmap='gray')

# %%
greyimage.shape
# Out:
# (617, 648)

# %%
greyimage[0,0]
# Out:
# 0.92941177

# %% [markdown]
# ### Colour images
#
# Colour images are represented as a 3-dimensional Numpy Array such that:
# - The first 2 dimensions represent the pixels of the image.
# - The last dimension represents the colour channels, it can be 3 or 4 channels:
#   - RGB: Red, Green, Blue
#   - RGBA: Red, Green, Blue, Alpha (transparency)

# %%
img = np.array([[[255,   0,   0], [  0, 255,   0], [  0,   0, 255]],   #  red,   green,     blue
                [[  0, 255, 255], [255,   0, 255], [255, 252,   0]],   # cyan, magenta,   yellow
                [[  0,   0,   0], [255, 255, 255], [127, 127, 127]]])  #black,   white, gray 50%
plt.axis("off")
plt.imshow(img)

# %%
img.shape
# Out:
# (3, 3, 3)

# %% [markdown]
# Let's read a colour image

# %%
stickanimals = plt.imread('Figs/stickanimals.jpg')
plt.imshow(stickanimals)

# %%
stickanimals.shape
# Out:
# (617, 648, 3)

# %%
print("Number type of each pixel:", type(stickanimals[0,0,0]))
# Out:
# Number type of each pixel: <class 'numpy.uint8'>

# %% [markdown]
# Let's print the three channels: Red, Green, Blue, side by side.

# %%
fig, axarray = plt.subplots(1, 3) # Create 3 subplots in one row, 3 columns
for i in range(3):
    axarray[i].imshow(stickanimals[:,:,i], cmap='gray')
    axarray[i].axis('off')

# %% [markdown]
# Let's now read an image from a .png file, which uses 4 channels, and convert it to 3 channels by removing the `alpha` channel.

# %%
stickanimalsRGBA = plt.imread('Figs/stickanimalsRGBA.png')
plt.imshow(stickanimalsRGBA)

# %%
print(stickanimalsRGBA.shape)
print("Number type of each pixel:", type(stickanimalsRGBA[0,0,0]))
# Out:
# (617, 648, 4)
# Number type of each pixel: <class 'numpy.float32'>

# %% [markdown]
# * PNG supports a fourth channel for every pixel. This extra channel, often called alpha, encodes transparency. This is the RGBA encoding.
# * The `imread` function encodes PNG files as floating point numbers from zero to one.
# * All other formats, like JPEG or BMP are encoded as integers from 0 to 255.

# %%
# This code is from https://www.linkedin.com/learning/computer-vision-deep-dive-in-python/
# To convert an RGBA image array that represents data with floating 
# point numbers from 0 to 1 into the RGB integer format from 0 to 255, 
# we need to change 4 things:

# 1) Get rid of the A channel
# 2) Multiply by 255
# 3) Round the resulting values
# 4) Ensure values are between 0 and 255
# 5) Convert data to 8-bit integers

# Let's define a function for this:

def adapt_PNG(the_PNG):
    the_PNG = the_PNG[:,:,:3]      # Step 1
    the_PNG = the_PNG * 255        # Step 2
    the_PNG = adapt_image(the_PNG) # Steps 3, 4, 5
    return the_PNG


# The following function will be useful to perform steps 3, 4, and 5 
# for RGB images in the 0-255 range, which are undergoing operations 
# that may result in floating point numbers.

def adapt_image(the_img):
    return np.uint8(np.clip(the_img.round(),0,255)) # Steps 3, 4, 5

# %%
converted_image = adapt_PNG(stickanimalsRGBA)
print('PNG image data type: ', type(converted_image[0,0,0]))
print(converted_image[0,0])
plt.imshow(converted_image)
plt.axis('off')
# Out:
# PNG image data type:  <class 'numpy.uint8'>
# [230 238 252]
# (-0.5, 647.5, 616.5, -0.5)

# %% [markdown]
# ## Take-home Messages
# * Get to learn Python.
#   * If you know how to program in another language, read this tutorial: https://docs.python.org/3/tutorial/index.html
# * Practice with Python’s `numpy` and `matplotlib` to read and manipulate images.
